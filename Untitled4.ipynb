# %% [markdown]
# <a href="https://colab.research.google.com/github/hayato-miura/Python_high_frequency/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# データ
slip = [0.00333, 0.0267, 0.0447, 0.0567, 0.07, 0.0867, 0.1]
torque = [0.030, 1.202, 1.925, 2.487, 2.930, 3.450, 3.722]
current = [1.423, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6]

# グラフの作成
fig, ax1 = plt.subplots()

ax1.set_xlabel('すべり')
ax1.set_ylabel('トルク [Nm]', color='tab:blue')
ax1.plot(slip, torque, 'o-', color='tab:blue', label='トルク [Nm]')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('一次電流 [A]', color='tab:orange')
ax2.plot(slip, current, 'o-', color='tab:orange', label='一次電流 [A]')
ax2.tick_params(axis='y', labelcolor='tab:orange')

fig.tight_layout()
plt.title('すべりに対するトルクと一次電流')
plt.show()
# Out:
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12377 (\N{HIRAGANA LETTER SU}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12409 (\N{HIRAGANA LETTER BE}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12426 (\N{HIRAGANA LETTER RI}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12488 (\N{KATAKANA LETTER TO}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12523 (\N{KATAKANA LETTER RU}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 12463 (\N{KATAKANA LETTER KU}) missing from current font.
#   fig.tight_layout()
# <ipython-input-1-1ed648308e5e>:21: UserWarning: Glyph 19968 (\N{CJK UNIFIED IDEOGRAPH-4E00}) missing from current font.
#   fig.tight_layout()
# ...

# %%
import matplotlib.pyplot as plt

# データ
mechanical_output = [4.696681, 183.7748, 288.8721, 368.5198, 428.0263, 494.9579, 526.1854]
rotation_speed = [1495, 1460, 1433, 1415, 1395, 1370, 1350]
efficiency = [5.571389, 65.96367, 72.01996, 74.25344, 73.50615, 75.02773, 71.22162]
torque = [0.03, 1.202, 1.925, 2.487, 2.93, 3.45, 3.722]
current = [1.423, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6]
power_factor = [0.170545, 0.500927, 0.643715, 0.716706, 0.763117, 0.795883, 0.824818]

fig, ax1 = plt.subplots()

# 横軸と左側の縦軸
ax1.set_xlabel('機械的出力 [W]')
ax1.set_ylabel('回転速度 [min^-1]', color='tab:blue')
ax1.plot(mechanical_output, rotation_speed, 'o-', color='tab:blue', label='回転速度 [min^-1]')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率のプロット
ax2 = ax1.twinx()
ax2.set_ylabel('効率 [%]', color='tab:green')
ax2.plot(mechanical_output, efficiency, 's-', color='tab:green', label='効率 [%]')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクのプロット
ax3 = ax1.twinx()
ax3.spines['left'].set_position(('outward', 60))
ax3.set_ylabel('トルク [Nm]', color='tab:red')
ax3.plot(mechanical_output, torque, 'd-', color='tab:red', label='トルク [Nm]')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 右側の縦軸
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('一次電流 [A]', color='tab:orange')
ax4.plot(mechanical_output, current, 'x-', color='tab:orange', label='一次電流 [A]')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率のプロット
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('力率', color='tab:purple')
ax5.plot(mechanical_output, power_factor, '*-', color='tab:purple', label='力率')
ax5.tick_params(axis='y', labelcolor='tab:purple')

fig.tight_layout()
plt.title('機械的出力に対する各特性の変化')
plt.show()
# Out:
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 27231 (\N{CJK UNIFIED IDEOGRAPH-6A5F}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 26800 (\N{CJK UNIFIED IDEOGRAPH-68B0}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.tight_layout()
# <ipython-input-3-e83b2aac8053>:46: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from current font.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# データの準備
data = {
    "端子電圧[V]": [200.55, 200.69, 199.86, 199.9, 200.25, 199.4, 198.9],
    "一次電流[A]": [1.423, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6],
    "一次入力[W]": [84.3, 278.6, 401.1, 496.3, 582.3, 659.7, 738.8],
    "トルク[Nm]": [0.03, 1.202, 1.925, 2.487, 2.93, 3.45, 3.722],
    "回転速度[min^-1]": [1495, 1460, 1433, 1415, 1395, 1370, 1350],
    "すべり": [0.00333, 0.0267, 0.0447, 0.0567, 0.07, 0.0867, 0.1],
    "力率": [0.170545, 0.500927, 0.643715, 0.716706, 0.763117, 0.795883, 0.824818],
    "機械的出力[W]": [4.696681, 183.7748, 288.8721, 368.5198, 428.0263, 494.9579, 526.1854],
    "効率[%]": [5.571389, 65.96367, 72.01996, 74.25344, 73.50615, 75.02773, 71.22162]
}

df = pd.DataFrame(data)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 機械的出力を横軸
ax1.set_xlabel('機械的出力 [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('回転速度 [min^-1]', color='tab:blue')
ax1.plot(df['機械的出力[W]'], df['回転速度[min^-1]'], 'o-', color='tab:blue', label='回転速度')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('効率 [%]', color='tab:green')
ax2.plot(df['機械的出力[W]'], df['効率[%]'], 's-', color='tab:green', label='効率')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('トルク [Nm]', color='tab:red')
ax3.plot(df['機械的出力[W]'], df['トルク[Nm]'], '^-', color='tab:red', label='トルク')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('一次電流 [A]', color='tab:orange')
ax4.plot(df['機械的出力[W]'], df['一次電流[A]'], 'd-', color='tab:orange', label='一次電流')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('力率', color='tab:purple')
ax5.plot(df['機械的出力[W]'], df['力率'], 'x-', color='tab:purple', label='力率')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('負荷試験の結果', y=1.05)
plt.show()
# Out:
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 27231 (\N{CJK UNIFIED IDEOGRAPH-6A5F}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 26800 (\N{CJK UNIFIED IDEOGRAPH-68B0}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.tight_layout()
# <ipython-input-4-1dd1a29ff0e2>:58: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from current font.
# ...

# %%
# データの準備
data = {
    "端子電圧[V]": [200.55, 200.69, 199.86, 199.9, 200.25, 199.4, 198.9],
    "一次電流[A]": [1.423, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6],
    "一次入力[W]": [84.3, 278.6, 401.1, 496.3, 582.3, 659.7, 738.8],
    "トルク[Nm]": [0.03, 1.202, 1.925, 2.487, 2.93, 3.45, 3.722],
    "回転速度[min^-1]": [1495, 1460, 1433, 1415, 1395, 1370, 1350],
    "すべり": [0.00333, 0.0267, 0.0447, 0.0567, 0.07, 0.0867, 0.1],
    "力率": [0.170545, 0.500927, 0.643715, 0.716706, 0.763117, 0.795883, 0.824818],
    "機械的出力[W]": [4.696681, 183.7748, 288.8721, 368.5198, 428.0263, 494.9579, 526.1854],
    "効率[%]": [5.571389, 65.96367, 72.01996, 74.25344, 73.50615, 75.02773, 71.22162]
}

df = pd.DataFrame(data)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 機械的出力を横軸
ax1.set_xlabel('機械的出力 [W]', fontsize=12)

# 回転速度を左縦軸に設定
ax1.set_ylabel('回転速度 [min^-1]', color='tab:blue', fontsize=12)
ax1.plot(df['機械的出力[W]'], df['回転速度[min^-1]'], 'o-', color='tab:blue', label='回転速度')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('効率 [%]', color='tab:green', fontsize=12)
ax2.plot(df['機械的出力[W]'], df['効率[%]'], 's-', color='tab:green', label='効率')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('トルク [Nm]', color='tab:red', fontsize=12)
ax3.plot(df['機械的出力[W]'], df['トルク[Nm]'], '^-', color='tab:red', label='トルク')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('一次電流 [A]', color='tab:orange', fontsize=12)
ax4.plot(df['機械的出力[W]'], df['一次電流[A]'], 'd-', color='tab:orange', label='一次電流')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('力率', color='tab:purple', fontsize=12)
ax5.plot(df['機械的出力[W]'], df['力率'], 'x-', color='tab:purple', label='力率')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('負荷試験の結果', y=1.05, fontsize=16)
plt.show()
# Out:
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 27231 (\N{CJK UNIFIED IDEOGRAPH-6A5F}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 26800 (\N{CJK UNIFIED IDEOGRAPH-68B0}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 20986 (\N{CJK UNIFIED IDEOGRAPH-51FA}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from current font.
#   fig.tight_layout()
# <ipython-input-7-548cf3890200>:55: UserWarning: Glyph 36578 (\N{CJK UNIFIED IDEOGRAPH-8EE2}) missing from current font.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# データの準備
data = {
    "Terminal Voltage [V]": [200.55, 200.69, 199.86, 199.9, 200.25, 199.4, 198.9],
    "Primary Current [A]": [1.423, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6],
    "Primary Input [W]": [84.3, 278.6, 401.1, 496.3, 582.3, 659.7, 738.8],
    "Torque [Nm]": [0.03, 1.202, 1.925, 2.487, 2.93, 3.45, 3.722],
    "Rotational Speed [min^-1]": [1495, 1460, 1433, 1415, 1395, 1370, 1350],
    "Slip": [0.00333, 0.0267, 0.0447, 0.0567, 0.07, 0.0867, 0.1],
    "Power Factor": [0.170545, 0.500927, 0.643715, 0.716706, 0.763117, 0.795883, 0.824818],
    "Mechanical Output [W]": [4.696681, 183.7748, 288.8721, 368.5198, 428.0263, 494.9579, 526.1854],
    "Efficiency [%]": [5.571389, 65.96367, 72.01996, 74.25344, 73.50615, 75.02773, 71.22162]
}

df = pd.DataFrame(data)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 機械的出力を横軸
ax1.set_xlabel('Mechanical Output [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(df['Mechanical Output [W]'], df['Rotational Speed [min^-1]'], 'o-', color='tab:blue', label='Rotational Speed')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(df['Mechanical Output [W]'], df['Efficiency [%]'], 's-', color='tab:green', label='Efficiency')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Torque [Nm]', color='tab:red')
ax3.plot(df['Mechanical Output [W]'], df['Torque [Nm]'], '^-', color='tab:red', label='Torque')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Primary Current [A]', color='tab:orange')
ax4.plot(df['Mechanical Output [W]'], df['Primary Current [A]'], 'd-', color='tab:orange', label='Primary Current')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('Power Factor', color='tab:purple')
ax5.plot(df['Mechanical Output [W]'], df['Power Factor'], 'x-', color='tab:purple', label='Power Factor')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Load Test Results', y=1.05)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# データの準備
data = {
    "Output Power [W]": [1.01911E-06, 69.3390969, 238.0205864, 379.9366542, 456.8861303, 508.6267585, 579.6470743, 636.0604989],
    "Torque [Nm]": [6.48784E-09, 0.444538168, 1.555735231, 2.532724464, 3.084440554, 3.466829242, 4.01103031, 4.464483903],
    "Efficiency [%]": [1.22843E-06, 40.9271394, 57.06973947, 59.61190111, 60.24419585, 60.45607459, 60.44042873, 60.12285391],
    "Rotational Speed [min^-1]": [1500, 1489.5, 1461, 1432.5, 1414.5, 1401, 1380, 1360.5],
    "Primary Current [A]": [1.420977957, 1.62472111, 2.155549325, 2.654025179, 2.952436024, 3.168077593, 3.489939629, 3.774436677],
    "Power Factor": [0.168535264, 0.301021381, 0.55854741, 0.693238318, 0.741517908, 0.766607081, 0.793281953, 0.809125841]
}

df = pd.DataFrame(data)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(df['Output Power [W]'], df['Rotational Speed [min^-1]'], 'o-', color='tab:blue', label='Rotational Speed')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(df['Output Power [W]'], df['Efficiency [%]'], 's-', color='tab:green', label='Efficiency')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Torque [Nm]', color='tab:red')
ax3.plot(df['Output Power [W]'], df['Torque [Nm]'], '^-', color='tab:red', label='Torque')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Primary Current [A]', color='tab:orange')
ax4.plot(df['Output Power [W]'], df['Primary Current [A]'], 'd-', color='tab:orange', label='Primary Current')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('Power Factor', color='tab:purple')
ax5.plot(df['Output Power [W]'], df['Power Factor'], 'x-', color='tab:purple', label='Power Factor')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Load Test Results', y=1.05)
plt.show()

# %%
import matplotlib.pyplot as plt

# データ
voltage = [15.68, 19.63, 23.77, 28.10, 31.48, 35.66, 40.07, 43.44, 48.41, 51.95, 56.05, 60.15]
torque = [0.018, 0.018, 0.018, 0.045, 0.075, 0.115, 0.165, 0.220, 0.285, 0.355, 0.415, 0.525]

# グラフの作成
plt.figure(figsize=(10, 6))
plt.scatter(voltage, torque, color='blue', label='Measured Torque')
plt.plot(voltage, torque, color='blue')

# グラフの設定
plt.title('Torque vs Input Voltage')
plt.xlabel('Input Voltage [V]')
plt.ylabel('Torque [N·m]')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# データの準備
output_power = np.array([1.01911E-06, 69.3390969, 238.0205864, 379.9366542, 456.8861303, 508.6267585, 579.6470743, 636.0604989])
torque = np.array([6.48784E-09, 0.444538168, 1.555735231, 2.532724464, 3.084440554, 3.466829242, 4.01103031, 4.464483903])
efficiency = np.array([1.22843E-06, 40.9271394, 57.06973947, 59.61190111, 60.24419585, 60.45607459, 60.44042873, 60.12285391])
rotational_speed = np.array([1500, 1489.5, 1461, 1432.5, 1414.5, 1401, 1380, 1360.5])
primary_current = np.array([1.420977957, 1.62472111, 2.155549325, 2.654025179, 2.952436024, 3.168077593, 3.489939629, 3.774436677])
power_factor = np.array([0.168535264, 0.301021381, 0.55854741, 0.693238318, 0.741517908, 0.766607081, 0.793281953, 0.809125841])

# 補間用のスムーズなカーブの作成
output_power_smooth = np.linspace(output_power.min(), output_power.max(), 500)

torque_smooth = make_interp_spline(output_power, torque)(output_power_smooth)
efficiency_smooth = make_interp_spline(output_power, efficiency)(output_power_smooth)
rotational_speed_smooth = make_interp_spline(output_power, rotational_speed)(output_power_smooth)
primary_current_smooth = make_interp_spline(output_power, primary_current)(output_power_smooth)
power_factor_smooth = make_interp_spline(output_power, power_factor)(output_power_smooth)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(output_power_smooth, rotational_speed_smooth, color='tab:blue', label='Rotational Speed')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(output_power_smooth, efficiency_smooth, color='tab:green', label='Efficiency')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Torque [Nm]', color='tab:red')
ax3.plot(output_power_smooth, torque_smooth, color='tab:red', label='Torque')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Primary Current [A]', color='tab:orange')
ax4.plot(output_power_smooth, primary_current_smooth, color='tab:orange', label='Primary Current')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('Power Factor', color='tab:purple')
ax5.plot(output_power_smooth, power_factor_smooth, color='tab:purple', label='Power Factor')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Load Test Results', y=1.05)
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
voltage = np.array([15.68, 19.63, 23.77, 28.10, 31.48, 35.66, 40.07, 43.44, 48.41, 51.95, 56.05, 60.15])
torque = np.array([0.018, 0.018, 0.018, 0.045, 0.075, 0.115, 0.165, 0.220, 0.285, 0.355, 0.415, 0.525])

# 二次関数の近似曲線を求める
coefficients = np.polyfit(voltage, torque, 2)
poly_fit = np.poly1d(coefficients)

# プロット用のx軸の範囲を定義
x_fit = np.linspace(min(voltage), max(voltage), 500)
y_fit = poly_fit(x_fit)

# グラフの作成
plt.figure(figsize=(10, 6))
plt.scatter(voltage, torque, color='blue', label='Measured Torque')
plt.plot(voltage, torque, color='blue')
plt.plot(x_fit, y_fit, color='red', linestyle='--', label='Quadratic Fit')

# グラフの設定
plt.title('Torque vs Input Voltage with Quadratic Fit')
plt.xlabel('Input Voltage [V]')
plt.ylabel('Torque [N·m]')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# データの準備
output_power = np.array([1.01911E-06, 69.3390969, 238.0205864, 379.9366542, 456.8861303, 508.6267585, 579.6470743, 636.0604989])
torque = np.array([6.48784E-09, 0.444538168, 1.555735231, 2.532724464, 3.084440554, 3.466829242, 4.01103031, 4.464483903])
efficiency = np.array([1.22843E-06, 40.9271394, 57.06973947, 59.61190111, 60.24419585, 60.45607459, 60.44042873, 60.12285391])
rotational_speed = np.array([1500, 1489.5, 1461, 1432.5, 1414.5, 1401, 1380, 1360.5])
primary_current = np.array([1.420977957, 1.62472111, 2.155549325, 2.654025179, 2.952436024, 3.168077593, 3.489939629, 3.774436677])
power_factor = np.array([0.168535264, 0.301021381, 0.55854741, 0.693238318, 0.741517908, 0.766607081, 0.793281953, 0.809125841])

# 補間用のスムーズなカーブの作成
output_power_smooth = np.linspace(output_power.min(), output_power.max(), 500)

torque_smooth = make_interp_spline(output_power, torque)(output_power_smooth)
efficiency_smooth = make_interp_spline(output_power, efficiency)(output_power_smooth)
rotational_speed_smooth = make_interp_spline(output_power, rotational_speed)(output_power_smooth)
primary_current_smooth = make_interp_spline(output_power, primary_current)(output_power_smooth)
power_factor_smooth = make_interp_spline(output_power, power_factor)(output_power_smooth)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(output_power_smooth, rotational_speed_smooth, color='tab:blue', label='Rotational Speed')
ax1.scatter(output_power, rotational_speed, color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(output_power_smooth, efficiency_smooth, color='tab:green', label='Efficiency')
ax2.scatter(output_power, efficiency, color='tab:green')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Torque [Nm]', color='tab:red')
ax3.plot(output_power_smooth, torque_smooth, color='tab:red', label='Torque')
ax3.scatter(output_power, torque, color='tab:red')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Primary Current [A]', color='tab:orange')
ax4.plot(output_power_smooth, primary_current_smooth, color='tab:orange', label='Primary Current')
ax4.scatter(output_power, primary_current, color='tab:orange')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('Power Factor', color='tab:purple')
ax5.plot(output_power_smooth, power_factor_smooth, color='tab:purple', label='Power Factor')
ax5.scatter(output_power, power_factor, color='tab:purple')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Load Test Results', y=1.05)
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
voltage = np.array([15.68, 19.63, 23.77, 28.10, 31.48, 35.66, 40.07, 43.44, 48.41, 51.95, 56.05, 60.15])
torque = np.array([0.018, 0.018, 0.018, 0.045, 0.075, 0.115, 0.165, 0.220, 0.285, 0.355, 0.415, 0.525])

# 二次関数の近似曲線を求める
coefficients = np.polyfit(voltage, torque, 2)
poly_fit = np.poly1d(coefficients)

# プロット用のx軸の範囲を定義
x_fit = np.linspace(min(voltage), max(voltage), 500)
y_fit = poly_fit(x_fit)

# 近似曲線の数式を文字列として保存
fit_equation = f'Torque = {coefficients[0]:.6f} * Voltage^2 + {coefficients[1]:.6f} * Voltage + {coefficients[2]:.6f}'

# グラフの作成
plt.figure(figsize=(10, 6))
plt.scatter(voltage, torque, color='blue', label='Measured Torque')
plt.plot(voltage, torque, color='blue')
plt.plot(x_fit, y_fit, color='red', linestyle='--', label='Quadratic Fit')

# 近似曲線の数式をグラフに表示
plt.text(0.05, 0.95, fit_equation, transform=plt.gca().transAxes, fontsize=12, verticalalignment='top')

# グラフの設定
plt.title('Torque vs Input Voltage with Quadratic Fit')
plt.xlabel('Input Voltage [V]')
plt.ylabel('Torque [N·m]')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# データの準備
output_power = np.array([1.01911E-06, 69.3390969, 238.0205864, 379.9366542, 456.8861303, 508.6267585, 579.6470743, 636.0604989])
torque = np.array([6.48784E-09, 0.444538168, 1.555735231, 2.532724464, 3.084440554, 3.466829242, 4.01103031, 4.464483903])
efficiency = np.array([1.22843E-06, 40.9271394, 57.06973947, 59.61190111, 60.24419585, 60.45607459, 60.44042873, 60.12285391])
rotational_speed = np.array([1500, 1489.5, 1461, 1432.5, 1414.5, 1401, 1380, 1360.5])
primary_current = np.array([1.420977957, 1.62472111, 2.155549325, 2.654025179, 2.952436024, 3.168077593, 3.489939629, 3.774436677])
power_factor = np.array([0.168535264, 0.301021381, 0.55854741, 0.693238318, 0.741517908, 0.766607081, 0.793281953, 0.809125841])

# 補間用のスムーズなカーブの作成
output_power_smooth = np.linspace(output_power.min(), output_power.max(), 500)

torque_smooth = make_interp_spline(output_power, torque)(output_power_smooth)
efficiency_smooth = make_interp_spline(output_power, efficiency)(output_power_smooth)
rotational_speed_smooth = make_interp_spline(output_power, rotational_speed)(output_power_smooth)
primary_current_smooth = make_interp_spline(output_power, primary_current)(output_power_smooth)
power_factor_smooth = make_interp_spline(output_power, power_factor)(output_power_smooth)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(output_power_smooth, rotational_speed_smooth, color='tab:blue', label='Rotational Speed')
ax1.scatter(output_power, rotational_speed, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(output_power_smooth, efficiency_smooth, color='tab:green', label='Efficiency')
ax2.scatter(output_power, efficiency, color='tab:green', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:green')

# トルクを追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Torque [Nm]', color='tab:red')
ax3.plot(output_power_smooth, torque_smooth, color='tab:red', label='Torque')
ax3.scatter(output_power, torque, color='tab:red', marker='^')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 一次電流を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Primary Current [A]', color='tab:orange')
ax4.plot(output_power_smooth, primary_current_smooth, color='tab:orange', label='Primary Current')
ax4.scatter(output_power, primary_current, color='tab:orange', marker='d')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# 力率を追加
ax5 = ax1.twinx()
ax5.spines['right'].set_position(('outward', 180))
ax5.set_ylabel('Power Factor', color='tab:purple')
ax5.plot(output_power_smooth, power_factor_smooth, color='tab:purple', label='Power Factor')
ax5.scatter(output_power, power_factor, color='tab:purple', marker='x')
ax5.tick_params(axis='y', labelcolor='tab:purple')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Load Test Results', y=1.05)
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# データの準備
output_power = np.array([2.974564644, 129.1927619, 192.149022, 244.0499129, 294.0178865, 340.7015345, 369.3851132, 406.1815407, 430.2222644])
rotational_speed = np.array([1495, 1460, 1438, 1415, 1392, 1367, 1352, 1322, 1296])
efficiency = np.array([4.721531181, 64.62869529, 70.0251538, 71.11011448, 71.1563133, 70.87612534, 69.55095334, 67.83258863, 65.87387297])
primary_current = np.array([1.0443, 1.2, 1.4, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6])
power_factor = np.array([0.209921009, 0.580743508, 0.685739018, 0.750009888, 0.801826861, 0.842845828, 0.84553266, 0.875890138, 0.880813522])

# 補間用のスムーズなカーブの作成
output_power_smooth = np.linspace(output_power.min(), output_power.max(), 500)
rotational_speed_smooth = make_interp_spline(output_power, rotational_speed)(output_power_smooth)
efficiency_smooth = make_interp_spline(output_power, efficiency)(output_power_smooth)
primary_current_smooth = make_interp_spline(output_power, primary_current)(output_power_smooth)
power_factor_smooth = make_interp_spline(output_power, power_factor)(output_power_smooth)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(output_power_smooth, rotational_speed_smooth, color='tab:blue', label='Rotational Speed')
ax1.scatter(output_power, rotational_speed, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(output_power_smooth, efficiency_smooth, color='tab:green', label='Efficiency')
ax2.scatter(output_power, efficiency, color='tab:green', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:green')

# 一次電流を追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Primary Current [A]', color='tab:red')
ax3.plot(output_power_smooth, primary_current_smooth, color='tab:red', label='Primary Current')
ax3.scatter(output_power, primary_current, color='tab:red', marker='^')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 力率を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Power Factor', color='tab:orange')
ax4.plot(output_power_smooth, power_factor_smooth, color='tab:orange', label='Power Factor')
ax4.scatter(output_power, power_factor, color='tab:orange', marker='d')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Output Characteristics', y=1.05)
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

# データの準備
output_power = np.array([9.581229275, 147.562073, 237.6887114, 302.4562044, 358.3066008, 412.7330181, 458.8695053, 508.3773403, 532.1495625])
rotational_speed = np.array([1794, 1757, 1730, 1707, 1688, 1663, 1643, 1622, 1591])
efficiency = np.array([13.21548866, 66.14167325, 73.27025628, 73.51876626, 73.45358771, 73.32261824, 72.51414432, 72.31541114, 69.07444996])
primary_current = np.array([1.0287, 1.2, 1.4, 1.6, 1.8, 2.0, 2.2, 2.4, 2.6])
power_factor = np.array([0.204987854, 0.542499937, 0.677643122, 0.753024186, 0.793256555, 0.82422132, 0.842124401, 0.861076967, 0.868568877])

# 補間用のスムーズなカーブの作成
output_power_smooth = np.linspace(output_power.min(), output_power.max(), 500)
rotational_speed_smooth = make_interp_spline(output_power, rotational_speed)(output_power_smooth)
efficiency_smooth = make_interp_spline(output_power, efficiency)(output_power_smooth)
primary_current_smooth = make_interp_spline(output_power, primary_current)(output_power_smooth)
power_factor_smooth = make_interp_spline(output_power, power_factor)(output_power_smooth)

# グラフの作成
fig, ax1 = plt.subplots(figsize=(12, 8))

# 出力電力を横軸
ax1.set_xlabel('Output Power [W]')

# 回転速度を左縦軸に設定
ax1.set_ylabel('Rotational Speed [min^-1]', color='tab:blue')
ax1.plot(output_power_smooth, rotational_speed_smooth, color='tab:blue', label='Rotational Speed')
ax1.scatter(output_power, rotational_speed, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# 効率を追加
ax2 = ax1.twinx()
ax2.set_ylabel('Efficiency [%]', color='tab:green')
ax2.plot(output_power_smooth, efficiency_smooth, color='tab:green', label='Efficiency')
ax2.scatter(output_power, efficiency, color='tab:green', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:green')

# 一次電流を追加
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
ax3.set_ylabel('Primary Current [A]', color='tab:red')
ax3.plot(output_power_smooth, primary_current_smooth, color='tab:red', label='Primary Current')
ax3.scatter(output_power, primary_current, color='tab:red', marker='^')
ax3.tick_params(axis='y', labelcolor='tab:red')

# 力率を追加
ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 120))
ax4.set_ylabel('Power Factor', color='tab:orange')
ax4.plot(output_power_smooth, power_factor_smooth, color='tab:orange', label='Power Factor')
ax4.scatter(output_power, power_factor, color='tab:orange', marker='d')
ax4.tick_params(axis='y', labelcolor='tab:orange')

# グラフのレイアウトを調整
fig.tight_layout()
fig.suptitle('Output Characteristics (60Hz)', y=1.05)
fig.legend(loc='upper left', bbox_to_anchor=(0.1,0.9))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# データ
voltage = np.array([15.68, 19.63, 23.77, 28.10, 31.48, 35.66, 40.07, 43.44, 48.41, 51.95, 56.05, 60.15])
torque = np.array([0.018, 0.018, 0.018, 0.045, 0.075, 0.115, 0.165, 0.220, 0.285, 0.355, 0.415, 0.525])

# 二次関数の近似曲線を求める
coefficients = np.polyfit(voltage, torque, 2)
poly_fit = np.poly1d(coefficients)

# プロット用のx軸の範囲を定義
x_fit = np.linspace(min(voltage), max(voltage), 500)
y_fit = poly_fit(x_fit)

# 近似曲線の数式を文字列として保存
fit_equation = f'Torque = {coefficients[0]:.6f} * Voltage^2 + {coefficients[1]:.6f} * Voltage + {coefficients[2]:.6f}'

# グラフの作成
plt.figure(figsize=(10, 6))
plt.scatter(voltage, torque, color='blue', label='Measured Torque')
plt.plot(voltage, torque, color='blue')
plt.plot(x_fit, y_fit, color='red', linestyle='--', label='Quadratic Fit')

# 近似曲線の数式をグラフの外に表示
plt.figtext(0.5, -0.1, fit_equation, ha="center", fontsize=12)

# グラフの設定
plt.title('Torque vs Input Voltage with Quadratic Fit')
plt.xlabel('Input Voltage [V]')
plt.ylabel('Torque [N·m]')
plt.legend(loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pip install matplotlib pandas
